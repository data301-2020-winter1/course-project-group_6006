# %% [markdown]
# # Exploring the data sets
#
# In this file I explore the red and white wine data sets using the commands from the seaborn tutorial
#
# Date: November 1, 2020
#
#
# I will start by looking at the data frame and the types of data in the columns, look for any missing values, and find how many duplicates there are.

# %% [markdown]
# ## Red Wine Data Set

# %% [markdown]
# ### Overview of Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

red_wine_df = pd.read_csv("../../data/raw/winequality-red.csv", sep=";")

red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Good, it looks like there are no missing values in the red wine dataframe and the value types are correct!

# %%
# generate count statistics of duplicate entries
# code from https://towardsdatascience.com/exploratory-data-analysis-eda-a-practical-guide-and-template-for-structured-data-abfbf3ee3bd9
if len(red_wine_df[red_wine_df.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(red_wine_df[red_wine_df.duplicated()]))
    print(red_wine_df[red_wine_df.duplicated(keep=False)].sort_values(by=list(red_wine_df.columns)).head())
else:
    print("No duplicated entries found")
# Out:
# No duplicated entries found

# %% [markdown]
# So there are 240 entries that should be removed with method chaining. We can also shorten some of the variable names.

# %%
red_wine_df = (
        red_wine_df
        .rename(columns={"fixed acidity": "fa", "volatile acidity": "va", "citric acid": "ca", "residual sugar": "rs", "free sulfur dioxide": "fsd", "total sulfur dioxide": "tsd"})
        .drop_duplicates()
        .dropna(axis=0, subset=['fa','va','ca','rs','chlorides','fsd','tsd','density','pH','sulphates','alcohol'])
    )
#red_wine_df.head()
# Out:
#      fa    va    ca   rs  chlorides   fsd   tsd  density    pH  sulphates  \
# 0   7.4  0.70  0.00  1.9      0.076  11.0  34.0   0.9978  3.51       0.56
# 1   7.8  0.88  0.00  2.6      0.098  25.0  67.0   0.9968  3.20       0.68
# 2   7.8  0.76  0.04  2.3      0.092  15.0  54.0   0.9970  3.26       0.65
# 3  11.2  0.28  0.56  1.9      0.075  17.0  60.0   0.9980  3.16       0.58
# 5   7.4  0.66  0.00  1.8      0.075  13.0  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 5      9.4        5

# %% [markdown]
# ---

# %% [markdown]
# ### Exploring Relationships
#
# Now I'll start looking at relationships between variables to find the variables of interest.
#
# I have the following research questions:
#
# 1. Which variable is most useful in determining the quality of a wine?
# 2. Which variables have the strongest relationship?
# 3. What properties are tied closest to a wine having a high alcohol percentage?
#
# I'll create a pandas profile to look at the variables in the data set.

# %%
from pandas_profiling import ProfileReport

prof = ProfileReport(red_wine_df)
prof.to_file(output_file='red_wine_pandas_profile.html')
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=27.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# Notes on the pandas profile:
# - The variables that have the strongest correlation are: pH and fixed acidity (-0.69), fixed acidity and citric acid (0.67), density and fixed acidity (0.67), alcohol and density (-0.5), citric acid and pH (-0.54), free sulfur dioxide and total sulfur dioxide (0.67) (these number are taken from the heat map below)
#     - the most interesting of these correlations is alcohol and density, so I will look at this more
#     - we are most concerned with the quality variable, and it is correlated most with volatile acidity and alcohol
# - There are outliers in every category other than density and quality
# - Most wines have an average quality, ranging from 5-6, but a few have very low quality (3-4) and high quality (7-8)

# %%
corr = red_wine_df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, 
            xticklabels=corr.columns, 
            yticklabels=corr.columns, 
            annot=True, 
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(red_wine_df, corner=True)

# %% [markdown]
# These pair plots confirm that the most distinct relationships appear to be between the density and fixed acidity, total sulfur dioxide and free sulfur dioxide, alcohol and density. The quality variable is difficult to visualize with these plots.

# %% [markdown]
# #### In the code blocks below I plot the numeric variables against the quality variable, which can be seen as categorical

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='residual sugar',data=white_wine_df)

plt.title("Quality vs Residual Sugar for White Wine")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='residual sugar',data=red_wine_df)

plt.title("Quality vs Residual Sugar for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Residual Sugar for Red Wine')

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='sulphates',data=red_wine_df)

plt.title("Quality vs Sulphates for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Sulphates for Red Wine')

# %% [markdown]
# High quality wines have a higher amount of sulphates

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='fixed acidity',data=red_wine_df)

plt.title("Quality vs Fixed Acidity for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Fixed Acidity for Red Wine')

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='volatile acidity',data=red_wine_df)

plt.title("Quality vs Volatile Acidity for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Volatile Acidity for Red Wine')

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='citric acid',data=red_wine_df)

plt.title("Quality vs Citric Acid for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Citric Acid for Red Wine')

# %% [markdown]
# Citric acid doesn't seem to have an effect on quality.

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='chlorides',data=red_wine_df)

plt.title("Quality vs Chlorides for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Chlorides for Red Wine')

# %% [markdown]
# This one seems interesting, high quality wines all have low chlorides

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='free sulfur dioxide',data=red_wine_df)

plt.title("Quality vs Free Sulfur Dioxide for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Free Sulfur Dioxide for Red Wine')

# %% [markdown]
# plt.figure(figsize=(8,5))
#
# sns.stripplot(x='quality',y='total sulfur dioxide',data=red_wine_df)
#
# plt.title("Quality vs Total Sulfur Dioxide for Red Wine")

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='density',data=red_wine_df)

plt.title("Quality vs Density for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs Density for Red Wine')

# %% [markdown]
# Low quality wines have higher densities.

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='pH',data=red_wine_df)

plt.title("Quality vs pH for Red Wine")
# Out:
# Text(0.5, 1.0, 'Quality vs pH for Red Wine')

# %%
red_wine_no_dup = red_wine_df.drop_duplicates()

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='quality',y='pH',data=red_wine_no_dup)

plt.title("Quality vs pH for Red Wine with no duplicates")
# Out:
# Text(0.5, 1.0, 'Quality vs pH for Red Wine with no duplicates')

# %% [markdown]
# ## White Wine Data Set

# %%
white_wine_df = pd.read_csv("../../data/raw/winequality-white.csv", sep=";")

white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# generate count statistics of duplicate entries
if len(white_wine_df[white_wine_df.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(white_wine_df[white_wine_df.duplicated()]))
    print(white_wine_df[white_wine_df.duplicated(keep=False)].sort_values(by=list(white_wine_df.columns)).head())
else:
    print("No duplicated entries found")

# %%
from pandas_profiling import ProfileReport

prof_white = ProfileReport(white_wine_df)
prof_white.to_file(output_file='white_wine_pandas_profile.html')
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=26.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
