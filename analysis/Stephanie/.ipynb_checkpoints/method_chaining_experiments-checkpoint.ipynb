# %% [markdown]
# # Working on Method Chaining
#
# In this script I explore method chaining.

# %%
import pandas as pd
import numpy as np

red_wine_df = (
        pd.read_csv("../../data/raw/winequality-white.csv", sep=";")
        .rename(columns={"fixed acidity": "fa", "volatile acidity": "va", "citric acid": "ca", "residual sugar": "rs", "free sulfur dioxide": "fsd", "total sulfur dioxide": "tsd"})
        .drop_duplicates()
    )
    
red_wine_df.head()
# Out:
#     fa    va    ca    rs  chlorides   fsd    tsd  density    pH  sulphates  \
# 0  7.0  0.27  0.36  20.7      0.045  45.0  170.0   1.0010  3.00       0.45
# 1  6.3  0.30  0.34   1.6      0.049  14.0  132.0   0.9940  3.30       0.49
# 2  8.1  0.28  0.40   6.9      0.050  30.0   97.0   0.9951  3.26       0.44
# 3  7.2  0.23  0.32   8.5      0.058  47.0  186.0   0.9956  3.19       0.40
# 6  6.2  0.32  0.16   7.0      0.045  30.0  136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 6      9.6        6

# %%
red_wine_df.shape
# Out:
# (3961, 12)

# %%
red_wine_df.describe()
# Out:
#                 fa           va           ca           rs    chlorides  \
# count  3961.000000  3961.000000  3961.000000  3961.000000  3961.000000
# mean      6.839346     0.280538     0.334332     5.914819     0.045905
# std       0.866860     0.103437     0.122446     4.861646     0.023103
# min       3.800000     0.080000     0.000000     0.600000     0.009000
# 25%       6.300000     0.210000     0.270000     1.600000     0.035000
# 50%       6.800000     0.260000     0.320000     4.700000     0.042000
# 75%       7.300000     0.330000     0.390000     8.900000     0.050000
# max      14.200000     1.100000     1.660000    65.800000     0.346000
#
#                fsd          tsd      density           pH    sulphates  \
# count  3961.000000  3961.000000  3961.000000  3961.000000  3961.000000
# mean     34.889169   137.193512     0.993790     3.195458     0.490351
# std      17.210021    43.129065     0.002905     0.151546     0.113523
# min       2.000000     9.000000     0.987110     2.720000     0.220000
# 25%      23.000000   106.000000     0.991620     3.090000     0.410000
# 50%      33.000000   133.000000     0.993500     3.180000     0.480000
# 75%      45.000000   166.000000     0.995710     3.290000     0.550000
# max     289.000000   440.000000     1.038980     3.820000     1.080000
#
#            alcohol      quality
# count  3961.000000  3961.000000
# mean     10.589358     5.854835
# std       1.217076     0.890683
# min       8.000000     3.000000
# 25%       9.500000     5.000000
# 50%      10.400000     6.000000
# 75%      11.400000     6.000000
# max      14.200000     9.000000
